# %% [markdown]
# ## Key Phases

# %% [markdown]
# 1. Data Exploration – finding out more about the data we have
# 2. Data Munging – cleaning the data and playing with it to make it better suit statistical modeling
# 3. Predictive Modeling – running the actual algorithms and having fun

# %% [markdown]
# ## Key Points (Python Data Structures)

# %% [markdown]
# Raw string in python:

# %%
raw_str = r'\nHey mini!!'
print (raw_str)
# Out:
# \nHey mini!!

# %% [markdown]
# **Tuples**  - A tuple is represented by a number of values separated by commas. Tuples are immutable and the output is surrounded by parentheses so that nested tuples are processed correctly. Additionally, even though tuples are immutable, they can hold mutable data if needed.
# Since Tuples are immutable and can not change, they are faster in processing as compared to lists. Hence, if your list is unlikely to change, you should use tuples, instead of lists.

# %%
import math as m
from math import *

# %% [markdown]
# In the first manner, we have defined an alias m to library math. We can now use various functions from math library (e.g. factorial) by referencing it using the alias m.factorial().
#
# In the second manner, you have imported the entire name space in math i.e. you can directly use factorial() without referring to math.
#
# **Google recommends that you use first style of importing libraries, as you will know where the functions have come from**

# %% [markdown]
# ## Pandas in Python

# %% [markdown]
# ### Series and Dataframes

# %% [markdown]
# **Series** - Series can be understood as a 1 dimensional labelled / indexed array. You can access individual elements of this series through these labels.
#
# **Dataframes** - A dataframe is similar to Excel workbook – you have column names referring to columns and you have rows, which can be accessed with use of row numbers. The essential difference being that column names and row numbers are known as column and row index, in case of dataframes.
#
# Series and dataframes form the core data model for Pandas in Python. The data sets are first read into these dataframes and then various operations (e.g. group by, aggregation etc.) can be applied very easily to its columns.

# %% [markdown]
# ### Data Dictionary
#
# ```
#
# Variable	          Description
#
# Loan_ID	                  Unique Loan ID
#
# Gender	                  Male/ Female
#
# Married	                  Applicant married (Y/N)
#
# Dependents	          Number of dependents
#
# Education	          Applicant Education (Graduate/ Under Graduate)
#
# Self_Employed	          Self employed (Y/N)
#
# ApplicantIncome	          Applicant income
#
# CoapplicantIncome	  Coapplicant income
#
# LoanAmount	          Loan amount in thousands
#
# Loan_Amount_Term	  Term of loan in months
#
# Credit_History	          credit history meets guidelines
#
# Property_Area	          Urban/ Semi Urban/ Rural
#
# Loan_Status	          Loan approved (Y/N)
#
# ```

# %%
# Importing required libraries

# %pylab inline

import matplotlib as plt
import numpy as np
import pylab
import pandas as pd

plt.style.use('bmh')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\magics\pylab.py:161: UserWarning: pylab import has clobbered these variables: ['fmod', 'sinh', 'trunc', 'tan', 'gamma', 'cosh', 'radians', 'sin', 'expm1', 'ldexp', 'exp', 'pylab', 'frexp', 'ceil', 'copysign', 'isnan', 'cos', 'degrees', 'pi', 'tanh', 'fabs', 'sqrt', 'hypot', 'table', 'log', 'log10', 'e', 'log1p', 'floor', 'modf', 'isinf']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
plot(arange(5))

# %%
df = pd.read_csv("D:/data_science-master/python for data science/Data Science with Python - AV/data/train.csv") #Reading the dataset in a dataframe using Pandas

df.head(10)

# df.describe() # Get summary of numerical vars
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
# 6             2333             1516.0        95.0             360.0
# 7             3036             2504.0       158.0             360.0
# 8             4006             1526.0       168.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# 7             0.0     Semiurban           N
# 8             1.0         Urban           Y
# 9             1.0     Semiurban           N

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# - LoanAmount has (614 – 592) 22 missing values.
# - Loan_Amount_Term has (614 – 600) 14 missing values.
# - Credit_History has (614 – 564) 50 missing values.
# - We can also look that about 84% applicants have a credit_history. How? The mean of Credit_History field is 0.84 (Remember, Credit_History has value 1 for those who have a credit history and 0 otherwise)
# - The ApplicantIncome distribution seems to be in line with expectation. Same with CoapplicantIncome
#
# ** we can get an idea of a possible skew in the data by comparing the mean to the median, i.e. the 50% figure. **
#
#
# ```
# In positive skew (right tail longer): mean > median > mode
# In negative skew (left tail longer): mode > median > mean
#
# ```
#
# ![skewness](http://www.statisticshowto.com/wp-content/uploads/2014/02/pearson-mode-skewness.jpg)

# %% [markdown]
# For the non-numerical values (e.g. Property_Area, Credit_History etc.), we can look at frequency distribution to understand whether they make sense or not. The frequency table can be printed by following command:

# %%
print (df['Property_Area'].value_counts() )
print (df['Gender'].value_counts() )
print (df['Married'].value_counts() )
print (df['Education'].value_counts() )
print (df['Self_Employed'].value_counts() )
print (df['Loan_Status'].value_counts() )
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# Male      489
# Female    112
# Name: Gender, dtype: int64
# Yes    398
# No     213
# Name: Married, dtype: int64
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
df['ApplicantIncome'].hist(bins=50)

# x axis: income, y axis: no of obs

# %% [markdown]
# Here we observe that there are few extreme values. This is also the reason why 50 bins are required to depict the distribution clearly.
#
# Next, we look at box plots to understand the distributions. Box plot for fare can be plotted by:

# %%
df.boxplot(column="ApplicantIncome")

# %% [markdown]
# This confirms the presence of a lot of outliers/extreme values. This can be attributed to the income disparity in the society. Part of this can be driven by the fact that we are looking at people with different education levels. Let us segregate them by Education:

# %%
df.boxplot(column="ApplicantIncome", by="Education")

# %% [markdown]
# We can see that there is no substantial different between the mean income of graduate and non-graduates. But there are a higher number of graduates with very high incomes, which are appearing to be the outliers.
#
# Now, Let’s look at the histogram and boxplot of LoanAmount using the following command:

# %%
df['LoanAmount'].hist(bins=50)

# %%
df.boxplot(column='LoanAmount')

# %% [markdown]
# LoanAmount has lots of outliers as well.
#
# LoanAmount has (614 – 592) 22 missing values.
#
# Clearly, both ApplicantIncome and LoanAmount require some amount of data munging. LoanAmount has missing and well as extreme values values, while ApplicantIncome has a few extreme values, which demand deeper understanding.

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# #### Categorical variable analysis
#
#
# Now that we understand distributions for ApplicantIncome and LoanIncome, let us understand categorical variables in more details. We will use Excel style pivot table and cross-tabulation. For instance, let us look at the chances of getting a loan based on credit history. This can be achieved in MS Excel using a pivot table as:
#
# ![pivot table](https://www.analyticsvidhya.com/wp-content/uploads/2016/01/10.-pivot_table3.png)
#
# **Note: here loan status has been coded as 1 for Yes and 0 for No. So the mean represents the probability of getting loan.**

# %%
temp1 = df['Credit_History'].value_counts()
print(temp1)


temp2 = df.pivot_table(values='Loan_Status', index=['Credit_History'],  aggfunc=lambda x: x.map({'Y':1, 'N':0}).mean())

print(temp2)
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64
#                 Loan_Status
# Credit_History
# 0.0                0.078652
# 1.0                0.795789

# %% [markdown]
# Now we can observe that we get a similar pivot_table like the MS Excel one. This can be plotted as a bar chart using the “matplotlib” library with following code:

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Credit History')
ax1.set_ylabel('Count of Applicants')
ax1.set_title('Count of Applicants by Credit History')
temp1.plot(kind='bar')


ax2 = fig.add_subplot(122)
temp2.plot(kind='bar', grid=False)
ax2.set_xlabel('Credit History')
ax2.set_ylabel('Probability of getting Loan')
ax2.set_title('Probability of getting Loan according to credit History')
# Out:
# Text(0.5,1,u'Probability of getting Loan according to credit History')

# %% [markdown]
# This shows that the chances of getting a loan are eight-fold if the applicant has a valid credit history. You can plot similar graphs by Married, Self-Employed, Property_Area, etc.
#
# #### Plotting similar graph for married feature

# %%
married_count = df['Married'].value_counts()

print(married_count)

married_pivot = df.pivot_table(values='Loan_Status', index=['Married', 'Credit_History'], aggfunc=lambda x: x.map({'Y':1, 'N':0}).mean())

print(married_pivot)

fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Married or not')
ax1.set_ylabel('Count of Applicants')
ax1.set_title('Count of Applicants by Marital Status')
married_count.plot(kind='bar')


ax2 = fig.add_subplot(122)
married_pivot.plot(kind='bar')
ax2.set_xlabel('Marital Status')
ax2.set_ylabel('Probability of getting Loan')
ax2.set_title('Probability of getting Loan according to Marital Status')
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64
#                         Loan_Status
# Married Credit_History
# No      0.0                0.093750
#         1.0                0.730539
# Yes     0.0                0.070175
#         1.0                0.829508
# Text(0.5,1,u'Probability of getting Loan according to Marital Status')

# %% [markdown]
# #### Plotting similar graph for Self-Employed feature

# %%
self_emp_count = df['Self_Employed'].value_counts()

self_emp_pivot = df.pivot_table(values='Loan_Status', index=['Self_Employed'], aggfunc=lambda x:x.map({'Y':1, 'N':0}).mean())

print(self_emp_pivot)


fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Self employed or not')
ax1.set_ylabel('Count of Applicants')
ax1.set_title('Count of Applicants by Emp Status')
self_emp_count.plot(kind='bar')


ax2 = fig.add_subplot(122)
self_emp_pivot.plot(kind='bar')
ax2.set_xlabel('Emp Status')
ax2.set_ylabel('Probability of getting Loan')
ax2.set_title('Probability of getting Loan according to Emp Status')
# Out:
#                Loan_Status
# Self_Employed
# No                0.686000
# Yes               0.682927
# Text(0.5,1,u'Probability of getting Loan according to Emp Status')

# %% [markdown]
# #### Plotting similar graph for Property_Area feature

# %%
prop_area_count = df['Property_Area'].value_counts()

print(prop_area_count)

prop_area_pivot = df.pivot_table(values='Loan_Status', index=['Property_Area'], aggfunc=lambda x: x.map({'Y':1, 'N':0}).mean())

print(prop_area_pivot)

fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Type of property area')
ax1.set_ylabel('Count of Applicants')
ax1.set_title('Count of Applicants by Prop Area')
prop_area_count.plot(kind='bar')


ax2 = fig.add_subplot(122)
prop_area_pivot.plot(kind='bar')
ax2.set_xlabel('Type of Prop Area')
ax2.set_ylabel('Probability of getting Loan')
ax2.set_title('Probability of getting Loan according to Prop Area')
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
#                Loan_Status
# Property_Area
# Rural             0.614525
# Semiurban         0.768240
# Urban             0.658416
# Text(0.5,1,u'Probability of getting Loan according to Prop Area')

# %%
temp3 = pd.crosstab(df['Credit_History'], df['Loan_Status'])

temp3
# Out:
# Loan_Status      N    Y
# Credit_History
# 0.0             82    7
# 1.0             97  378

# %%
temp3.plot(kind='bar', stacked=True)

# %% [markdown]
# #### Data Munging in Python : Using Pandas
#
# While our exploration of the data, we found a few problems in the data set, which needs to be solved before the data is ready for a good model. This exercise is typically referred as “Data Munging”. Here are the problems, we are already aware of:
#
# 1. There are missing values in some variables. We should estimate those values wisely depending on the amount of missing values and the expected importance of variables.
#
# 2. While looking at the distributions, we saw that ApplicantIncome and LoanAmount seemed to contain extreme values at either end. Though they might make intuitive sense, but should be treated appropriately.
#
# In addition to these problems with numerical fields, we should also look at the non-numerical fields i.e. Gender, Property_Area, Married, Education and Dependents to see, if they contain any useful information.
#
# #### Check missing values in our dataset:
#
# Let us look at missing values in all the variables because most of the models don’t work with missing data and even if they do, imputing them helps more often than not. So, let us check the number of nulls / NaNs in the dataset

# %%
# axis:0 probably tells it to go col-wise

df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# Missing values are not always only in the form of NaN. So we should check each categorical column separately
#
# **Note: Remember that missing values may not always be NaNs. For instance, if the Loan_Amount_Term is 0, does it makes sense or would you consider that missing? I suppose your answer is missing and you’re right. So we should check for values which are unpractical.**

# %%
print (df['Gender'].value_counts())
print (df['Married'].value_counts())
print (df['Self_Employed'].value_counts())
print (df['Credit_History'].value_counts())
print (df['Property_Area'].value_counts())
print (df['Loan_Status'].value_counts())


# returns an empty dataframe
print (df[df['Loan_Amount_Term']==0])
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64
# Yes    398
# No     213
# Name: Married, dtype: int64
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %% [markdown]
# #### Filling missing values for Loan Amount
#
# There are numerous ways to fill the missing values of loan amount – the simplest being replacement by mean, which can be done by following code:
#
# ```
#  df['LoanAmount'].fillna(df['LoanAmount'].mean(), inplace=True)
# ```
#
# The other extreme could be to build a supervised learning model to predict loan amount on the basis of other variables and then use age along with other variables to predict survival.
# ___
#
# Let's find a trade-off between the two
#
# **Hypothesis: whether a person is educated or self-employed can combine to give a good estimate of loan amount.**

# %%
edu_count = df['Education'].value_counts()

print (edu_count)

edu_emp_pivot = df.pivot_table(values='LoanAmount', index=['Education', 'Self_Employed'], aggfunc=lambda x: x.median())

print (edu_emp_pivot)

fig = plt.figure(figsize=(12, 4))

edu_emp_pivot.plot(kind='bar')
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
#                             LoanAmount
# Education    Self_Employed
# Graduate     No                  130.0
#              Yes                 157.5
# Not Graduate No                  113.0
#              Yes                 130.0

# %% [markdown]
# Thus we see some variations in the median of loan amount for each group and this can be used to impute the values. But first, we have to ensure that each of Self_Employed and Education variables should not have a missing values.

# %%
df['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %% [markdown]
# Since ~86% values are “No”, it is safe to impute the missing values as “No” as there is a high probability of success. This can be done using the following code:

# %%
df['Self_Employed'].fillna('No', inplace=True)

# %%
df['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %% [markdown]
# **Education has no missing values**

# %% [markdown]
# Now, we will create a Pivot table, which provides us median values for all the groups of unique values of Self_Employed and Education features.

# %%
table = df.pivot_table(values='LoanAmount', index='Self_Employed' ,columns='Education', aggfunc=np.median)

table
# Out:
# Education      Graduate  Not Graduate
# Self_Employed
# No                130.0         113.0
# Yes               157.5         130.0

# %% [markdown]
# Next, we define a function, which returns the values of these cells and apply it to fill the missing values of loan amount:

# %%
def fage(x):
    print(x)
    print(table.loc[x['Self_Employed'], x['Education']])
    return table.loc[x['Self_Employed'], x['Education']]

df['LoanAmount'].fillna(df[df['LoanAmount'].isnull()].apply(fage, axis=1), inplace=True)
# Out:
# Loan_ID              LP001002
# Gender                   Male
# Married                    No
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          5849
# CoapplicantIncome           0
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Urban
# Loan_Status                 Y
# Name: 0, dtype: object
# 130.0
# Loan_ID              LP001106
# Gender                   Male
# Married                   Yes
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          2275
# CoapplicantIncome        2067
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Urban
# Loan_Status                 Y
# Name: 35, dtype: object
# 130.0
# Loan_ID              LP001213
# Gender                   Male
# Married                   Yes
# Dependents                  1
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          4945
# CoapplicantIncome           0
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              0
# Property_Area           Rural
# Loan_Status                 N
# Name: 63, dtype: object
# 130.0
# Loan_ID               LP001266
# Gender                    Male
# Married                    Yes
# Dependents                   1
# Education             Graduate
# Self_Employed              Yes
# ApplicantIncome           2395
# CoapplicantIncome            0
# LoanAmount                 NaN
# Loan_Amount_Term           360
# Credit_History               1
# Property_Area        Semiurban
# Loan_Status                  Y
# Name: 81, dtype: object
# 157.5
# Loan_ID              LP001326
# Gender                   Male
# Married                    No
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          6782
# CoapplicantIncome           0
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History            NaN
# Property_Area           Urban
# Loan_Status                 N
# Name: 95, dtype: object
# 130.0
# Loan_ID              LP001350
# Gender                   Male
# Married                   Yes
# Dependents                NaN
# Education            Graduate
# Self_Employed              No
# ApplicantIncome         13650
# CoapplicantIncome           0
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Urban
# Loan_Status                 Y
# Name: 102, dtype: object
# 130.0
# Loan_ID               LP001356
# Gender                    Male
# Married                    Yes
# Dependents                   0
# Education             Graduate
# Self_Employed               No
# ApplicantIncome           4652
# CoapplicantIncome         3583
# LoanAmount                 NaN
# Loan_Amount_Term           360
# Credit_History               1
# Property_Area        Semiurban
# Loan_Status                  Y
# Name: 103, dtype: object
# 130.0
# Loan_ID               LP001392
# Gender                  Female
# Married                     No
# Dependents                   1
# Education             Graduate
# Self_Employed              Yes
# ApplicantIncome           7451
# CoapplicantIncome            0
# LoanAmount                 NaN
# Loan_Amount_Term           360
# Credit_History               1
# Property_Area        Semiurban
# Loan_Status                  Y
# Name: 113, dtype: object
# 157.5
# Loan_ID              LP001449
# Gender                   Male
# Married                    No
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          3865
# CoapplicantIncome        1640
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Rural
# Loan_Status                 Y
# Name: 127, dtype: object
# 130.0
# Loan_ID                  LP001682
# Gender                       Male
# Married                       Yes
# Dependents                     3+
# Education            Not Graduate
# Self_Employed                  No
# ApplicantIncome              3992
# CoapplicantIncome               0
# LoanAmount                    NaN
# Loan_Amount_Term              180
# Credit_History                  1
# Property_Area               Urban
# Loan_Status                     N
# Name: 202, dtype: object
# 113.0
# Loan_ID              LP001922
# Gender                   Male
# Married                   Yes
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome         20667
# CoapplicantIncome           0
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Rural
# Loan_Status                 N
# Name: 284, dtype: object
# 130.0
# Loan_ID                  LP001990
# Gender                       Male
# Married                        No
# Dependents                      0
# Education            Not Graduate
# Self_Employed                  No
# ApplicantIncome              2000
# CoapplicantIncome               0
# LoanAmount                    NaN
# Loan_Amount_Term              360
# Credit_History                  1
# Property_Area               Urban
# Loan_Status                     N
# Name: 305, dtype: object
# 113.0
# Loan_ID                  LP002054
# Gender                       Male
# Married                       Yes
# Dependents                      2
# Education            Not Graduate
# Self_Employed                  No
# ApplicantIncome              3601
# CoapplicantIncome            1590
# LoanAmount                    NaN
# Loan_Amount_Term              360
# Credit_History                  1
# Property_Area               Rural
# Loan_Status                     Y
# Name: 322, dtype: object
# 113.0
# Loan_ID                  LP002113
# Gender                     Female
# Married                        No
# Dependents                     3+
# Education            Not Graduate
# Self_Employed                  No
# ApplicantIncome              1830
# CoapplicantIncome               0
# LoanAmount                    NaN
# Loan_Amount_Term              360
# Credit_History                  0
# Property_Area               Urban
# Loan_Status                     N
# Name: 338, dtype: object
# 113.0
# Loan_ID                  LP002243
# Gender                       Male
# Married                       Yes
# Dependents                      0
# Education            Not Graduate
# Self_Employed                  No
# ApplicantIncome              3010
# CoapplicantIncome            3136
# LoanAmount                    NaN
# Loan_Amount_Term              360
# Credit_History                  0
# Property_Area               Urban
# Loan_Status                     N
# Name: 387, dtype: object
# 113.0
# Loan_ID               LP002393
# Gender                  Female
# Married                    NaN
# Dependents                 NaN
# Education             Graduate
# Self_Employed               No
# ApplicantIncome          10047
# CoapplicantIncome            0
# LoanAmount                 NaN
# Loan_Amount_Term           240
# Credit_History               1
# Property_Area        Semiurban
# Loan_Status                  Y
# Name: 435, dtype: object
# 130.0
# Loan_ID              LP002401
# Gender                   Male
# Married                   Yes
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          2213
# CoapplicantIncome        1125
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Urban
# Loan_Status                 Y
# Name: 437, dtype: object
# 130.0
# Loan_ID              LP002533
# Gender                   Male
# Married                   Yes
# Dependents                  2
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          2947
# CoapplicantIncome        1603
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              1
# Property_Area           Urban
# Loan_Status                 N
# Name: 479, dtype: object
# 130.0
# Loan_ID               LP002697
# Gender                    Male
# Married                     No
# Dependents                   0
# Education             Graduate
# Self_Employed               No
# ApplicantIncome           4680
# CoapplicantIncome         2087
# LoanAmount                 NaN
# Loan_Amount_Term           360
# Credit_History               1
# Property_Area        Semiurban
# Loan_Status                  N
# Name: 524, dtype: object
# 130.0
# Loan_ID              LP002778
# Gender                   Male
# Married                   Yes
# Dependents                  2
# Education            Graduate
# Self_Employed             Yes
# ApplicantIncome          6633
# CoapplicantIncome           0
# LoanAmount                NaN
# Loan_Amount_Term          360
# Credit_History              0
# Property_Area           Rural
# Loan_Status                 N
# Name: 550, dtype: object
# 157.5
# Loan_ID                  LP002784
# Gender                       Male
# Married                       Yes
# Dependents                      1
# Education            Not Graduate
# Self_Employed                  No
# ApplicantIncome              2492
# CoapplicantIncome            2375
# LoanAmount                    NaN
# Loan_Amount_Term              360
# Credit_History                  1
# Property_Area               Rural
# Loan_Status                     Y
# Name: 551, dtype: object
# 113.0
# Loan_ID                  LP002960
# Gender                       Male
# Married                       Yes
# Dependents                      0
# Education            Not Graduate
# Self_Employed                  No
# ApplicantIncome              2400
# CoapplicantIncome            3800
# LoanAmount                    NaN
# Loan_Amount_Term              180
# Credit_History                  1
# Property_Area               Urban
# Loan_Status                     N
# Name: 605, dtype: object
# 113.0

# %% [markdown]
# > ```x['Self_Employed'] will be Yes or No
# x['Education'] will be Graduate or Not Graduate
# table.loc[x['Self_Employed'], x['Education']] will return the median LoanAmount for the filters: Self_Employed and Education
# ```

# %% [markdown]
# #### At this stage we have imputed the missing values of LoanAmount

# %%
df['LoanAmount'].hist(bins=50)

# %%
df['ApplicantIncome'].hist(bins=50)

# %% [markdown]
# #### There are extreme values for LoanAmount and ApplicantIncome.. We need to treat them
#
# Let’s analyze LoanAmount first. Since the extreme values are practically possible, i.e. some people might apply for high value loans due to specific needs. So instead of treating them as outliers, let’s try a log transformation to nullify their effect:

# %%
df['LoanAmount_log'] = np.log(df['LoanAmount'])

df['LoanAmount_log'].hist(bins=50)

# %% [markdown]
# Now the distribution looks much closer to normal and effect of extreme values has been significantly subsided.

# %% [markdown]
# Coming to ApplicantIncome. One intuition can be that some applicants have lower income but strong support Co-applicants. So it might be a good idea to combine both incomes as total income and take a log transformation of the same.

# %%
df['TotalIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']

df['TotalIncome_log'] = np.log(df['TotalIncome'])

df['TotalIncome_log'].hist(bins=20)

# %% [markdown]
# Now we see that the distribution is much better than before.

# %% [markdown]
# #### Imputing missing values for Gender
#
# There are 13 missing vales for **Gender**

# %%
gender_count = df['Gender'].value_counts()

print(gender_count)

print("% of male:", gender_count[0]*100/(gender_count[0]+gender_count[1]))
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64
# ('% of male:', 81)

# %% [markdown]
# #### Since 81% of data is for male, we can impute missing values as Male

# %%
df['Gender'].fillna('Male', inplace=True)

print (df['Gender'].value_counts())
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %% [markdown]
# #### Imputing missing values for Married

# %%
df['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
married_coapp_pivot = df.pivot_table(values='CoapplicantIncome', index=['Married', 'Gender'], aggfunc=lambda x: x.median())

print(married_coapp_pivot)
# Out:
#                 CoapplicantIncome
# Married Gender
# No      Female                0.0
#         Male                  0.0
# Yes     Female             1459.0
#         Male               1625.0

# %% [markdown]
# #### Most Not Self Employed People are not married!

# %%
non_self_emp_df = df[df['Self_Employed'] == 'No']

print ("Non Self Emp Count:", len(non_self_emp_df))

married_non_self_emp_df = non_self_emp_df[non_self_emp_df['Married'] == 'No']

married_non_self_emp_df
# Out:
# ('Non Self Emp Count:', 532)
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 15   LP001032    Male      No          0      Graduate            No
# 16   LP001034    Male      No          1  Not Graduate            No
# 17   LP001036  Female      No          0      Graduate            No
# 28   LP001086    Male      No          0  Not Graduate            No
# 29   LP001087  Female      No          2      Graduate            No
# 31   LP001095    Male      No          0      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 38   LP001114    Male      No          0      Graduate            No
# 39   LP001116    Male      No          0  Not Graduate            No
# 40   LP001119    Male      No          0      Graduate            No
# 41   LP001120    Male      No          0      Graduate            No
# 45   LP001137  Female      No          0      Graduate            No
# 49   LP001151  Female      No          0      Graduate            No
# 51   LP001157  Female      No          0      Graduate            No
# 52   LP001164  Female      No          0      Graduate            No
# 64   LP001222  Female      No          0      Graduate            No
# 66   LP001228    Male      No          0  Not Graduate            No
# 69   LP001241  Female      No          0      Graduate            No
# 72   LP001248    Male      No          0      Graduate            No
# 75   LP001255    Male      No          0      Graduate            No
# 76   LP001256    Male      No          0      Graduate            No
# 80   LP001265  Female      No          0      Graduate            No
# 85   LP001279    Male      No          0      Graduate            No
# 88   LP001289    Male      No          0      Graduate            No
# 93   LP001322    Male      No          0      Graduate            No
# 94   LP001325    Male      No          0  Not Graduate            No
# 95   LP001326    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 510  LP002637    Male      No          0  Not Graduate            No
# 514  LP002652    Male      No          0      Graduate            No
# 518  LP002683    Male      No          0      Graduate            No
# 519  LP002684  Female      No          0  Not Graduate            No
# 521  LP002690    Male      No          0      Graduate            No
# 524  LP002697    Male      No          0      Graduate            No
# 528  LP002714    Male      No          1  Not Graduate            No
# 529  LP002716    Male      No          0  Not Graduate            No
# 532  LP002723    Male      No          2      Graduate            No
# 533  LP002729    Male      No          1      Graduate            No
# 535  LP002732    Male      No          0  Not Graduate            No
# 537  LP002738    Male      No          2      Graduate            No
# 541  LP002743  Female      No          0      Graduate            No
# 542  LP002753  Female      No          1      Graduate            No
# 546  LP002768    Male      No          0  Not Graduate            No
# 547  LP002772    Male      No          0      Graduate            No
# 548  LP002776  Female      No          0      Graduate            No
# 556  LP002794  Female      No          0      Graduate            No
# 566  LP002836    Male      No          0      Graduate            No
# 568  LP002840  Female      No          0      Graduate            No
# 577  LP002874    Male      No          0      Graduate            No
# 579  LP002888    Male      No          0      Graduate            No
# 581  LP002893    Male      No          0      Graduate            No
# 587  LP002917  Female      No          0  Not Graduate            No
# 588  LP002925    Male      No          0      Graduate            No
# 595  LP002940    Male      No          0  Not Graduate            No
# 597  LP002943    Male      No        NaN      Graduate            No
# 600  LP002949  Female      No         3+      Graduate            No
# 603  LP002958    Male      No          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       130.0             360.0
# 4               6000                0.0       141.0             360.0
# 13              1853             2840.0       114.0             360.0
# 15              4950                0.0       125.0             360.0
# 16              3596                0.0       100.0             240.0
# 17              3510                0.0        76.0             360.0
# 28              1442                0.0        35.0             360.0
# 29              3750             2083.0       120.0             360.0
# 31              3167                0.0        74.0             360.0
# 34             12500             3000.0       320.0             360.0
# 38              4166             7210.0       184.0             360.0
# 39              3748             1668.0       110.0             360.0
# 40              3600                0.0        80.0             360.0
# 41              1800             1213.0        47.0             360.0
# 45              3410                0.0        88.0               NaN
# 49              4000             2275.0       144.0             360.0
# 51              3086                0.0       120.0             360.0
# 52              4230                0.0       112.0             360.0
# 64              4166                0.0       116.0             360.0
# 66              3200             2254.0       126.0             180.0
# 69              4300                0.0       136.0             360.0
# 72              3500                0.0        81.0             300.0
# 75              3750                0.0       113.0             480.0
# 76              3750             4750.0       176.0             360.0
# 80              3846                0.0       111.0             360.0
# 85              2366             2531.0       136.0             360.0
# 88              8566                0.0       210.0             360.0
# 93              4133                0.0       122.0             360.0
# 94              3620                0.0        25.0             120.0
# 95              6782                0.0       130.0             360.0
# ..               ...                ...         ...               ...
# 510             3598             1287.0       100.0             360.0
# 514             5815             3666.0       311.0             360.0
# 518             4683             1915.0       185.0             360.0
# 519             3400                0.0        95.0             360.0
# 521             2500                0.0        55.0             360.0
# 524             4680             2087.0       130.0             360.0
# 528             2679             1302.0        94.0             360.0
# 529             6783                0.0       130.0             360.0
# 532             3588                0.0       110.0             360.0
# 533            11250                0.0       196.0             360.0
# 535             2550             2042.0       126.0             360.0
# 537             3617                0.0       107.0             360.0
# 541             2138                0.0        99.0             360.0
# 542             3652                0.0        95.0             360.0
# 546             3358                0.0        80.0              36.0
# 547             2526             1783.0       145.0             360.0
# 548             5000                0.0       103.0             360.0
# 556             2667             1625.0        84.0             360.0
# 566             3333                0.0        70.0             360.0
# 568             2378                0.0         9.0             360.0
# 577             3229             2739.0       110.0             360.0
# 579             3182             2917.0       161.0             360.0
# 581             1836            33837.0        90.0             360.0
# 587             2165                0.0        70.0             360.0
# 588             4750                0.0        94.0             360.0
# 595             3833                0.0       110.0             360.0
# 597             2987                0.0        88.0             360.0
# 600              416            41667.0       350.0             180.0
# 603             3676             4301.0       172.0             360.0
# 609             2900                0.0        71.0             360.0
#
#      Credit_History Property_Area Loan_Status  LoanAmount_log  TotalIncome  \
# 0               1.0         Urban           Y        4.867534       5849.0
# 4               1.0         Urban           Y        4.948760       6000.0
# 13              1.0         Rural           N        4.736198       4693.0
# 15              1.0         Urban           Y        4.828314       4950.0
# 16              NaN         Urban           Y        4.605170       3596.0
# 17              0.0         Urban           N        4.330733       3510.0
# 28              1.0         Urban           N        3.555348       1442.0
# 29              1.0     Semiurban           Y        4.787492       5833.0
# 31              1.0         Urban           N        4.304065       3167.0
# 34              1.0         Rural           N        5.768321      15500.0
# 38              1.0         Urban           Y        5.214936      11376.0
# 39              1.0     Semiurban           Y        4.700480       5416.0
# 40              1.0         Urban           N        4.382027       3600.0
# 41              1.0         Urban           Y        3.850148       3013.0
# 45              1.0         Urban           Y        4.477337       3410.0
# 49              1.0     Semiurban           Y        4.969813       6275.0
# 51              1.0     Semiurban           Y        4.787492       3086.0
# 52              1.0     Semiurban           N        4.718499       4230.0
# 64              0.0     Semiurban           N        4.753590       4166.0
# 66              0.0         Urban           N        4.836282       5454.0
# 69              0.0     Semiurban           N        4.912655       4300.0
# 72              1.0     Semiurban           Y        4.394449       3500.0
# 75              1.0         Urban           N        4.727388       3750.0
# 76              1.0         Urban           N        5.170484       8500.0
# 80              1.0     Semiurban           Y        4.709530       3846.0
# 85              1.0     Semiurban           Y        4.912655       4897.0
# 88              1.0         Urban           Y        5.347108       8566.0
# 93              1.0     Semiurban           Y        4.804021       4133.0
# 94              1.0     Semiurban           Y        3.218876       3620.0
# 95              NaN         Urban           N        4.867534       6782.0
# ..              ...           ...         ...             ...          ...
# 510             1.0         Rural           N        4.605170       4885.0
# 514             1.0         Rural           N        5.739793       9481.0
# 518             1.0     Semiurban           N        5.220356       6598.0
# 519             1.0         Rural           N        4.553877       3400.0
# 521             1.0     Semiurban           Y        4.007333       2500.0
# 524             1.0     Semiurban           N        4.867534       6767.0
# 528             1.0     Semiurban           Y        4.543295       3981.0
# 529             1.0     Semiurban           Y        4.867534       6783.0
# 532             0.0         Rural           N        4.700480       3588.0
# 533             NaN     Semiurban           N        5.278115      11250.0
# 535             1.0         Rural           Y        4.836282       4592.0
# 537             1.0     Semiurban           Y        4.672829       3617.0
# 541             0.0     Semiurban           N        4.595120       2138.0
# 542             1.0     Semiurban           Y        4.553877       3652.0
# 546             1.0     Semiurban           N        4.382027       3358.0
# 547             1.0         Rural           Y        4.976734       4309.0
# 548             0.0     Semiurban           N        4.634729       5000.0
# 556             NaN         Urban           Y        4.430817       4292.0
# 566             1.0         Urban           Y        4.248495       3333.0
# 568             1.0         Urban           N        2.197225       2378.0
# 577             1.0         Urban           Y        4.700480       5968.0
# 579             1.0         Urban           Y        5.081404       6099.0
# 581             1.0         Urban           N        4.499810      35673.0
# 587             1.0     Semiurban           Y        4.248495       2165.0
# 588             1.0     Semiurban           Y        4.543295       4750.0
# 595             1.0         Rural           Y        4.700480       3833.0
# 597             0.0     Semiurban           N        4.477337       2987.0
# 600             NaN         Urban           N        5.857933      42083.0
# 603             1.0         Rural           Y        5.147494       7977.0
# 609             1.0         Rural           Y        4.262680       2900.0
#
#      TotalIncome_log
# 0           8.674026
# 4           8.699515
# 13          8.453827
# 15          8.507143
# 16          8.187577
# 17          8.163371
# 28          7.273786
# 29          8.671287
# 31          8.060540
# 34          9.648595
# 38          9.339261
# 39          8.597113
# 40          8.188689
# 41          8.010692
# 45          8.134468
# 49          8.744329
# 51          8.034631
# 52          8.349957
# 64          8.334712
# 66          8.604105
# 69          8.366370
# 72          8.160518
# 75          8.229511
# 76          9.047821
# 80          8.254789
# 85          8.496378
# 88          9.055556
# 93          8.326759
# 94          8.194229
# 95          8.822027
# ..               ...
# 510         8.493925
# 514         9.157045
# 518         8.794522
# 519         8.131531
# 521         7.824046
# 524         8.819813
# 528         8.289288
# 529         8.822175
# 532         8.185350
# 533         9.328123
# 535         8.432071
# 537         8.193400
# 541         7.667626
# 542         8.203030
# 546         8.119101
# 547         8.368461
# 548         8.517193
# 556         8.364508
# 566         8.111628
# 568         7.774015
# 577         8.694167
# 579         8.715880
# 581        10.482149
# 587         7.680176
# 588         8.465900
# 595         8.251403
# 597         8.002025
# 600        10.647399
# 603         8.984318
# 609         7.972466
#
# [185 rows x 16 columns]
