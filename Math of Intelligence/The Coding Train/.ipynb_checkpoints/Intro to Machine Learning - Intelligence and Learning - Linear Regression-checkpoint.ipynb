# %% [markdown]
# ### Session 3 - Intro to Machine Learning - Intelligence and Learning
#
# [Playlist link](https://www.youtube.com/playlist?list=PLRqwX-V7Uu6bCN8LKrcMa6zF4FPtXyXYj)
#
# [Lesson README link](https://github.com/shiffman/NOC-S17-2-Intelligence-Learning/tree/master/week3-classification-regression)
#
# ### 3.2: Linear Regression with Ordinary Least Squares Part 1 - Intelligence and Learning
#
# Consider ice cream sales with temp
#
# We plot the data using a scatter plot
#
# It appears as if there is a linear rel in the data
#
# ![](./data/img/diag2.png)
#
# Idea of LinReg is to figure out how can we best fit a line to this data, so that given any temp we can estimate the sales

# %% [markdown]
# How to find this best fit line?
#
# - There are many methods. One of them is **Ordinary Least Squares**
#
# We haave fit a line to the data
#
# We can also calculate the distance of the actual data points from the line i.e the diff (error) bw the actual and predicted values for a given temp
#
# **Ordinary Least Squares: we want to find a line that minimizes all of these distances**
#
# ![](./data/img/diag3.png)
#
# say distances as shown are d0, d1, d2..
#
# We want to find a best fit line that minimizes do^2 + d1^2 + d2^2 + ...
#
# Why sq? - Some of the distances are -ve
#
# ---
#
# The formula for a st line is y = mx + b
#
# Here we have only one ind var i.e temp
#
# But there can be multiple features like hours the shop is open, population etc
#
# In general formula is : y = b0 + b1x1 + b2x2 + ...
#
# This is called **Multiple Lin Reg**
#
# ---
#
# To get y = mx + b
#
# We have to get m and b
#
# **Formula for m:**
#
# ![](./data/img/diag4.png)
#
# Say y = x
#
# Slope is 1
#
# In formula, (y - ybar ) = (x - xbar)
#
# so m = 1
#
#
#
# **Formula for b**:
#
# y = mx + b
#
# b = y - mx
#
# We just use the avg of all the y and x
#
# b = ybar - m*xbar

# %% [markdown]
# ### 3.3: Linear Regression with Ordinary Least Squares Part 2 - Intelligence and Learning
#
# [YouTube link](https://www.youtube.com/watch?v=_cXuvTQl090&index=6&list=PLRqwX-V7Uu6bCN8LKrcMa6zF4FPtXyXYj)
#
# We want to build an interactive system
#
# We want to build a canvas on which an user can click and a point gets generated. And we find the best fit line for this new data
#
# First we need a canvas
#
# ``` javascript
# // create a canvas (400x400) and set a grayish background
#     createCanvas(400, 400);
#     background(51);
# ```
#
# But in browser canvas (0,0) is in top left
#
# In our case (0,0) should be in bottom left
#
# So we need to **map our pixel space**
#
# So (0,0) should be in bottom left and X axis should go from 0 to 1
# And Y axis should also go from 0 to 1
#
# How we do this is:
#
# ``` javascript
# var x = map(mouseX, 0, width, 0, 1)
#
# var y = map(mouseY, 0, height, 1, 0)
#
# ```
#
# mouseX can go bw 0 and width of canvas
# We map it to 0 and 1 resp
#
# mouseY can also go from 0 to height
# mouse Y if 0 we map it to 1
# if height we map it to 0

# %% [markdown]
# Code to get point on click:
#
# ``` javascript
#
# function mousePressed(){
#     // whenever i press the mouse i am going to create a new data point
#
#     var x = map(mouseX, 0, width, 0, 1);
#     var y = map(mouseY, 0, height, 1, 0);
#
#     var point = createVector(x, y);
#     data.push(point);
# }
#
# function draw(){
#     background(51);
#
#     for (var i = 0; i < data.length; ++i){
#         // map back to pixel range
#
#         var x = map(data[i].x, 0, 1, 0, width);
#         var y = map(data[i].y, 0, 1, height, 0);
#
#         //draw an ellipse at that pt of 8x8
#         fill(255);
#         stroke(255);
#         ellipse(x, y, 8, 8)
#
#
#     }
#
# }
#
# ```
#
# Now we need the best fit line
#
# Lets assume values of m and b for the time being
#
# ``` javascript
#
# var m = 1;
# var b = 0;
#
# ```
#
# Drawing the line. We calculate y values for x = 0 and x = 1 and plot the line using m and b
#
# ``` javascript
#
# function drawLine(){
#
#     // this function draws a line for m and b
#
#     var x1 = 0;
#     var y1 = m*x1 + b;
#     var x2 = 1;
#     var y2 = m*x2 + b;
#
#     x1 = map(x1, 0, 1, 0, width);
#     y1 = map(y1, 0, 1, height, 0);
#     x2 = map(x2, 0, 1, 0, width);
#     y2 = map(y2, 0, 1, height, 0);
#
#     stroke(255);
#     line(x1, y1, x2, y2);
# }
#
# ```
#
# Getting the values of m and b:
#
# ``` javascript
#
# function linearRegression(){
#     var xsum = 0;
#     var ysum = 0;
#     for(var i = 0; i < data.length; ++i){
#         xsum += data[i].x;
#         ysum += data[i].y;
#     }
#     var xmean = xsum/data.length;
#     var ymean = ysum/data.length;
#
#     var numerator = 0;
#     var denominator = 0;
#
#     for(var i = 0; i < data.length; ++i){
#         var x = data[i].x;
#         var y = data[i].y;
#         numerator += (x - xmean) * (y - ymean);
#         denominator += (x - xmean) * (x - xmean);
#     }
#
#     m = numerator/denominator;
#
#     b = ymean - m * xmean;
# }
# ```

# %% [markdown]
# #### When should we actually use a LinReg model
#
# Often its better to fit a curve to the data, rather than a linear line
#
# This is called **Polynomial Regression**
#
# One way to figure out if LinReg is correct choice is by loking at the **Residual plot**
#
# [Interactive example](https://kwichmann.github.io/ml_sandbox/linear_regression_diagnostics/)
#
# ![](./data/img/diag5.png)
#
# Here we can see that the residual plot is **random, on either side of x axis**. So LinReg is a good fit
#
# ![](./data/img/diag6.png)
#
# Here the residual plot follows ssome kind of a pattern. So LinReg is not a good fit
#
#
# Another method of doing LinReg is **Gradient Descent**
#
# This method is widely used while building Neural Networks
#
# [LinReg with Gradient Descent](link)
